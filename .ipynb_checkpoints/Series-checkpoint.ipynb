# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\vitth\AppData\Roaming\Python\Python313\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\vitth\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\vitth\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\vitth\AppData\Roaming\Python\Python313\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\vitth\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas Series
# A Series is a one-dimensional labeled array capable of holding any data type. The axis labels are collectively called the index.
#
# Creating Series
# There are multiple ways to create a pandas Series:

# %%
labels = ['a' , 'b' ,'c']
my_list = [ 10 , 20 , 30]
arr=np.array([10,20,30])
dict = {1:2 , 3:4 , 5:6}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list , index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1    2
# 3    4
# 5    6
# dtype: int64
